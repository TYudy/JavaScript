# %% [markdown]
# # Pandas

# %% [markdown]
# En pandas hay dos objetos principales: **Pandas Series** y **Pandas DataFrame**.
#
# Pandas Series: es muy parecido a un array de una dimensión (o vector) de Numpy.
# - Arreglo unidimensional indexado
# - Búsqueda por índice
# - Slicing
# - Operaciones aritméticas
# - Distintos tipos de datos
#
# Pandas DataFrame: muy parecido a las estructuras matriciales trabajadas con Numpy.
# - Estructura principal
# - Arreglo de dos dimensiones
# - Búsqueda por índice (columnas o filas)
# - Slicing
# - Operaciones aritméticas
# - Distintos tipos de datos
# - Tamaño variable

# %%
import pandas as pd

# %% [markdown]
# ## Crear una Serie

# %% [markdown]
# Si no especifíco los índices entonces toma un lista ordenada comenzando desde cero.

# %%
pd.Series(["Futbol","Carros","Rios","Peces"])
# Out:
# 0    Futbol
# 1    Carros
# 2      Rios
# 3     Peces
# dtype: object

# %%
cosas=pd.Series(["Futbol","Carros","Rios","Peces"],index=[2,3,7,9])
cosas
# Out:
# 2    Futbol
# 3    Carros
# 7      Rios
# 9     Peces
# dtype: object

# %% [markdown]
# También puedo definir una serie a partir de un diccionario de Python

# %%
dic={2:"Futbol",3:"Carros",7:"Rios",9:"Peces"}
pd.Series(dic)
# Out:
# 2    Futbol
# 3    Carros
# 7      Rios
# 9     Peces
# dtype: object

# %% [markdown]
# Puedo acceder a los elementos a través del índice.

# %%
dic[7]
# Out:
# 'Rios'

# %% [markdown]
# Y también mediante slicing.

# %%
cosas[:2]
# Out:
# 2    Futbol
# 3    Carros
# dtype: object

# %% [markdown]
# ## Crear un DataFrame

# %% [markdown]
# Si quiero una estructura matricial con varios parámetros entonces lo mejor es utilizar un dataframe.

# %%
diccionario = {"Lenguaje": ["Python","C","Java","C++"],
               "Demanda":[290,95,240,95],
               "Tipo":["Interpretado","Compilado","Interpretado/Compilado","Compilado"]}
df = pd.DataFrame(diccionario,index=[1,2,3,4])
df
# Out:
#   Lenguaje  Demanda                    Tipo
# 1   Python      290            Interpretado
# 2        C       95               Compilado
# 3     Java      240  Interpretado/Compilado
# 4      C++       95               Compilado

# %% [markdown]
# Visualizar las columnas.

# %%
df.columns
# Out:
# Index(['Lenguaje', 'Demanda', 'Tipo'], dtype='object')

# %% [markdown]
# Visualizar los índices.

# %%
df.index
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %% [markdown]
# ## Leer archivos CSV y JSON

# %% [markdown]
# Para leer un archivo **CSV** lo hago con *pd.read_csv()*.

# %%
pd.read_csv("bestsellers-with-categories.csv")
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Si nuestro archivo no está delimitado por comas sino, por ejemplo, por / entonces usamos *sep="delimitador"*.

# %%
pd.read_csv("bestsellers-with-categories.csv",sep=",")
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# También es posible que muchos archivos no tengan un encabezado o **header** donde están los nombres de las columnas.
#
# En ese caso, con *header = None*; con *header = 0* especificamos que la fila es el encabezado.

# %%
pd.read_csv("bestsellers-with-categories.csv",sep=",",header=0)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# También puedo especificar el nombre de las columnas con *names = [nombres]*

# %%
pd.read_csv("bestsellers-with-categories.csv",sep=",",header=0,names=["Hola","papa"])
# Out:
#                                                                                           Hola  \
# 10-Day Green Smoothie Cleanse                      JJ Smith                 4.7 17350 8   2016
# 11/22/63: A Novel                                  Stephen King             4.6 2052  22  2011
# 12 Rules for Life: An Antidote to Chaos            Jordan B. Peterson       4.7 18979 15  2018
# 1984 (Signet Classics)                             George Orwell            4.7 21424 6   2017
# 5,000 Awesome Facts (About Everything!) (Nation... National Geographic Kids 4.8 7665  12  2019
# ...                                                                                        ...
# Wrecking Ball (Diary of a Wimpy Kid Book 14)       Jeff Kinney              4.9 9413  8   2019
# You Are a Badass: How to Stop Doubting Your Gre... Jen Sincero              4.7 14331 8   2016
#                                                                                       8   2017
#                                                                                       8   2018
#                                                                                       8   2019
#
#                                                                                                  papa
# 10-Day Green Smoothie Cleanse                      JJ Smith                 4.7 17350 8   Non Fiction
# 11/22/63: A Novel                                  Stephen King             4.6 2052  22      Fiction
# 12 Rules for Life: An Antidote to Chaos            Jordan B. Peterson       4.7 18979 15  Non Fiction
# 1984 (Signet Classics)                             George Orwell            4.7 21424 6       Fiction
# 5,000 Awesome Facts (About Everything!) (Nation... National Geographic Kids 4.8 7665  12  Non Fiction
# ...                                                                                               ...
# Wrecking Ball (Diary of a Wimpy Kid Book 14)       Jeff Kinney              4.9 9413  8       Fiction
# You Are a Badass: How to Stop Doubting Your Gre... Jen Sincero              4.7 14331 8   Non Fiction
#                                                                                       8   Non Fiction
#                                                                                       8   Non Fiction
#                                                                                       8   Non Fiction
#
# [550 rows x 2 columns]

# %% [markdown]
# También podemos leer archivos **JSON** utilizando *pd.read_json()*.

# %%
pd.read_json("hpcharactersdata.json")
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
#                                                   Descr  Gender Species/Race  \
# 0     Mrs. Abbott was the mother of Hannah Abbott, a...  Female        Witch
# 1     Hannah Abbott is a Hufflepuff student in Harry...  Female        Witch
# 2     Abel Treetops was a wizard from Cincinnati who...    Male       Wizard
# 3     Euan Abercrombie was a small boy with prominen...    Male       Wizard
# 4     Aberforth Dumbledore was a tall, thin, grumpy-...    Male       Wizard
# ...                                                 ...     ...          ...
# 1935  Georgi Zdravko played Keeper for the Bulgarian...    Male       Wizard
# 1936  Zograf played Keeper for the Bulgarian Nationa...     NaN       Wizard
# 1937  Founder(?) of Zonko’s Joke Shop. Possibly a re...     NaN      Unknown
# 1938  Valentina Vázquez was President of the Argenti...  Female        Witch
# 1939  Zygmunt Budge is considered to be one of the m...    Male       Wizard
#
#             Blood                 School  \
# 0     Muggle-born                Unknown
# 1      Half-blood  Hogwarts - Hufflepuff
# 2         Unknown                Unknown
# 3         Unknown  Hogwarts - Gryffindor
# 4      Half-blood     Hogwarts - Student
# ...           ...                    ...
# 1935      Unknown                Unknown
# 1936      Unknown                Unknown
# 1937      Unknown                Unknown
# 1938      Unknown                Unknown
# 1939      Unknown     Hogwarts - Student
#
#                                          Profession
# 0                                           Unknown
# 1                    Landlady of the Leaky Cauldron
# 2                                           Unknown
# 3                                           Unknown
# 4                                            Barman
# ...                                             ...
# 1935                      Quidditch player (Seeker)
# 1936                      Quidditch player (Keeper)
# 1937                                        Unknown
# 1938  President of the Argentinian Council of Magic
# 1939    Potions Master, Potioneer, Inventor, Author
#
# [1940 rows x 8 columns]

# %% [markdown]
# ## Filtrado con iloc y loc

# %% [markdown]
# Permiten filtrar datos de manera mas específica. *loc* filtra segun un label mientras que *iloc* lo hace mediante índices.

# %%
libros=pd.read_csv("bestsellers-with-categories.csv")
libros
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
libros[["Name","Price"]]
# Out:
#                                                   Name  Price
# 0                        10-Day Green Smoothie Cleanse      8
# 1                                    11/22/63: A Novel     22
# 2              12 Rules for Life: An Antidote to Chaos     15
# 3                               1984 (Signet Classics)      6
# 4    5,000 Awesome Facts (About Everything!) (Natio...     12
# ..                                                 ...    ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      8
# 546  You Are a Badass: How to Stop Doubting Your Gr...      8
# 547  You Are a Badass: How to Stop Doubting Your Gr...      8
# 548  You Are a Badass: How to Stop Doubting Your Gr...      8
# 549  You Are a Badass: How to Stop Doubting Your Gr...      8
#
# [550 rows x 2 columns]

# %% [markdown]
# *loc* nos permite, por ejemplo, filtrar filas.

# %%
libros.loc[:]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# También podemos especificar un rango y hay que tener en cuenta que incluye ambos extremos.

# %%
libros.iloc[:2]
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# *loc* nos permite combinar el filtrado de filas y columnas(labels).

# %%
libros.loc[:10,["Name","Price"]]
# Out:
#                                                  Name  Price
# 0                       10-Day Green Smoothie Cleanse      8
# 1                                   11/22/63: A Novel     22
# 2             12 Rules for Life: An Antidote to Chaos     15
# 3                              1984 (Signet Classics)      6
# 4   5,000 Awesome Facts (About Everything!) (Natio...     12
# 5       A Dance with Dragons (A Song of Ice and Fire)     11
# 6   A Game of Thrones / A Clash of Kings / A Storm...     30
# 7                      A Gentleman in Moscow: A Novel     15
# 8       A Higher Loyalty: Truth, Lies, and Leadership      3
# 9                           A Man Called Ove: A Novel      8
# 10                          A Man Called Ove: A Novel      8

# %% [markdown]
# Podemos hacer cosas más complejas como modificar los valores de una columna específica.

# %%
libros.loc[:10,["Price"]]*-1
# Out:
#     Price
# 0      -8
# 1     -22
# 2     -15
# 3      -6
# 4     -12
# 5     -11
# 6     -30
# 7     -15
# 8      -3
# 9      -8
# 10     -8

# %% [markdown]
# Y podemos filtrar a partir de una condición. Esto nos arroja una Serie booleana.

# %%
libros.loc[:,["Author"]]=="Stephen King"
# Out:
#      Author
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %% [markdown]
# *iloc* nos permite hacer un filtrado a través de los índices.

# %%
libros.iloc[:]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Como estamos haciendo la búsqueda por índice entonces el final no se incluye.

# %%
libros.iloc[:3]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %% [markdown]
# Podemos filtrar los datos según el índice de las filas y de las columnas.

# %%
libros.iloc[:3,2:4]
# Out:
#    User Rating  Reviews
# 0          4.7    17350
# 1          4.6     2052
# 2          4.7    18979

# %% [markdown]
# Y también podemos buscar un dato específico.

# %%
libros.iloc[1,3]
# Out:
# 2052

# %% [markdown]
# Y luego modificarlo.

# %%
libros.iloc[1,3]=50
libros.iloc[1,3]
# Out:
# 50

# %%
libros.iloc[:3,2:4]
# Out:
#    User Rating  Reviews
# 0          4.7    17350
# 1          4.6       50
# 2          4.7    18979

# %% [markdown]
# ## Agregar o eliminar datos

# %% [markdown]
# Con *.head()* vemos las primeras 5 líneas del dataframe.

# %%
#import numpy as np
libros.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6       50     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Eliminar columnas de la salida pero no del dataframe.

# %%
#axis = 1 para columnas
libros.drop("Author",axis=1).head()
# Out:
#                                                 Name  User Rating  Reviews  \
# 0                      10-Day Green Smoothie Cleanse          4.7    17350
# 1                                  11/22/63: A Novel          4.6       50
# 2            12 Rules for Life: An Antidote to Chaos          4.7    18979
# 3                             1984 (Signet Classics)          4.7    21424
# 4  5,000 Awesome Facts (About Everything!) (Natio...          4.8     7665
#
#    Price  Year        Genre
# 0      8  2016  Non Fiction
# 1     22  2011      Fiction
# 2     15  2018  Non Fiction
# 3      6  2017      Fiction
# 4     12  2019  Non Fiction

# %% [markdown]
# Eliminar una columna del dataframe.

# %%
#del libros["Genre"]
libros
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year
# 0                    JJ Smith          4.7    17350      8  2016
# 1                Stephen King          4.6       50     22  2011
# 2          Jordan B. Peterson          4.7    18979     15  2018
# 3               George Orwell          4.7    21424      6  2017
# 4    National Geographic Kids          4.8     7665     12  2019
# ..                        ...          ...      ...    ...   ...
# 545               Jeff Kinney          4.9     9413      8  2019
# 546               Jen Sincero          4.7    14331      8  2016
# 547               Jen Sincero          4.7    14331      8  2017
# 548               Jen Sincero          4.7    14331      8  2018
# 549               Jen Sincero          4.7    14331      8  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# Eliminar filas de la salida pero no del dataframe.

# %%
libros.drop(1,axis=0).head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year
# 0                  JJ Smith          4.7    17350      8  2016
# 2        Jordan B. Peterson          4.7    18979     15  2018
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019
# 5       George R. R. Martin          4.4    12643     11  2011

# %% [markdown]
# Eliminar un conjunto de filas mediante una lista.

# %%
libros.drop([0,2,7],axis=0).head()
# Out:
#                                                 Name  \
# 1                                  11/22/63: A Novel
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
#
#                      Author  User Rating  Reviews  Price  Year
# 1              Stephen King          4.6       50     22  2011
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019
# 5       George R. R. Martin          4.4    12643     11  2011
# 6       George R. R. Martin          4.7    19735     30  2014

# %% [markdown]
# Eliminar un conjunto de filas a través de un rango.

# %%
libros.drop(range(0,50),axis=0).head()
# Out:
#                                                  Name           Author  \
# 50        Crazy Love: Overwhelmed by a Relentless God     Francis Chan
# 51        Crazy Love: Overwhelmed by a Relentless God     Francis Chan
# 52        Crazy Love: Overwhelmed by a Relentless God     Francis Chan
# 53      Crazy Rich Asians (Crazy Rich Asians Trilogy)       Kevin Kwan
# 54  Creative Haven Creative Cats Coloring Book (Ad...  Marjorie Sarnat
#
#     User Rating  Reviews  Price  Year
# 50          4.7     1542     14  2009
# 51          4.7     1542     14  2010
# 52          4.7     1542     14  2011
# 53          4.3     6143      8  2018
# 54          4.8     4022      4  2015

# %% [markdown]
# Agregar una nueva columna con valores **NaN**.

# %%
libros["goku ultra institnto nivel un millon xd"]=pd.NA
libros.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7    17350      8  2016
# 1              Stephen King          4.6       50     22  2011
# 2        Jordan B. Peterson          4.7    18979     15  2018
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019
#
#   goku ultra institnto nivel un millon xd
# 0                                    <NA>
# 1                                    <NA>
# 2                                    <NA>
# 3                                    <NA>
# 4                                    <NA>

# %% [markdown]
# Mostrar el número de filas de un dataframe.

# %%
libros.shape[0]
# Out:
# 550

# %% [markdown]
# Mostrar el número de columnas de un dataframe.

# %%
libros.shape[1]
# Out:
# 7

# %% [markdown]
# Agregar valores a una nueva columna del dataframe.

# %%
import numpy as np
Nuevo=np.arange(0,libros.shape[0])
libros["Nuevo2"]=Nuevo
libros.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7    17350      8  2016
# 1              Stephen King          4.6       50     22  2011
# 2        Jordan B. Peterson          4.7    18979     15  2018
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019
#
#   goku ultra institnto nivel un millon xd  Nuevo2
# 0                                    <NA>       0
# 1                                    <NA>       1
# 2                                    <NA>       2
# 3                                    <NA>       3
# 4                                    <NA>       4

# %% [markdown]
# Agregar filas.

# %%
pd.concat([libros,libros])
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year  \
# 0                    JJ Smith          4.7    17350      8  2016
# 1                Stephen King          4.6       50     22  2011
# 2          Jordan B. Peterson          4.7    18979     15  2018
# 3               George Orwell          4.7    21424      6  2017
# 4    National Geographic Kids          4.8     7665     12  2019
# ..                        ...          ...      ...    ...   ...
# 545               Jeff Kinney          4.9     9413      8  2019
# 546               Jen Sincero          4.7    14331      8  2016
# 547               Jen Sincero          4.7    14331      8  2017
# 548               Jen Sincero          4.7    14331      8  2018
# 549               Jen Sincero          4.7    14331      8  2019
#
#     goku ultra institnto nivel un millon xd  Nuevo2
# 0                                       NaN       0
# 1                                       NaN       1
# 2                                       NaN       2
# 3                                       NaN       3
# 4                                       NaN       4
# ..                                      ...     ...
# 545                                     NaN     545
# 546                                     NaN     546
# 547                                     NaN     547
# 548                                     NaN     548
# 549                                     NaN     549
#
# [1100 rows x 8 columns]

# %% [markdown]
# Como vemos, ahora hay 1100 filas, o sea, se duplicaron.

# %% [markdown]
# ## Manejo de datos nulos

# %%
diccionario = {'Col1':[1,2,3,np.nan],
'Col2':[4, np.nan,6,7],
'Col3':['a','b','c', None]}
df = pd.DataFrame(diccionario)
df
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %% [markdown]
# Identificar valores nulos en un dataframe.

# %%
df.isnull()
# Out:
#    Lenguaje  Demanda   Tipo
# 1     False    False  False
# 2     False    False  False
# 3     False    False  False
# 4     False    False  False

# %% [markdown]
# Identificar los valores nulos con un valor numérico.

# %%
df.isnull()*1
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %% [markdown]
# Sustituir los valores nulos por un string.

# %%
df.fillna("Vacio")
# Out:
#     Col1   Col2   Col3
# 0    1.0    4.0      a
# 1    2.0  Vacio      b
# 2    3.0    6.0      c
# 3  Vacio    7.0  Vacio

# %% [markdown]
# Sustituir los valores nulos por la media realizada con los valores de las columnas.

# %%
df.fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.ffill(df.mean())
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Sustituir valores nulos por valores de interpolación.
#
# METHOD: método usado par interpolar. Por default es el linear. Pero existen otros:
# - Time: para interpolar entre intervalos de tiempo.
# - Index: reemplaza el nulo por el valor del index.
# - Pad: reemplaza el nulo por algún valor existente en el dataframe.
# - Se puede especificar que la interpolación sea cuadrática, cúbica , polinómica, entre otros.
# - Se puede especificar que se reemplace por el cero, o el valor contiguo más cercano, entre otros.
#
# AXIS: tiene 3 opciones:
# - En dirección de los index (axis = 0).
# - En dirección de las columnas (axis = 1).
# - None: ninguna. Esta es la opción default.
#
# LIMIT (opcional) : el número máximo de NULOS consecutivos que se pueden reemplazar. Tiene que ser mayor a cero.
#
# LIMIT_DIRECTION (opcional): idem anterior pero en alguna dirección. Puede ser:
# - Forward: hacia adelante.
# - Backward: hacia atrás.
# - Both: ambos.

# %%
df.interpolate()
# Out:
# C:\Users\SENA\AppData\Local\Temp\ipykernel_18952\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %% [markdown]
# Eliminar valores nulos.

# %%
df.dropna()
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# Utilizando *inplace = True* podemos eliminar los na del dataframe.

# %%
df.dropna(inplace=True)
df
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# ## Filtrado por condiciones

# %%
libros=pd.read_csv("bestsellers-with-categories.csv")
libros.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Mostrar datos que cumplan una condición. Esto devuelve una Serie booleana.

# %%
mayor=libros["Year"]>2016
mayor
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 545     True
# 546    False
# 547     True
# 548     True
# 549     True
# Name: Year, Length: 550, dtype: bool

# %% [markdown]
# Podemos utilizar la condición para obtener los valores.

# %%
libros[mayor]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 7                 Amor Towles          4.7    19699     15  2017      Fiction
# 8                 James Comey          4.7     5983      3  2018  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 544             R. J. Palacio          4.8    21625      9  2017      Fiction
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [150 rows x 7 columns]

# %% [markdown]
# O colocar directamente una condición.

# %%
libros[libros["Year"]>2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 7                 Amor Towles          4.7    19699     15  2017      Fiction
# 8                 James Comey          4.7     5983      3  2018  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 544             R. J. Palacio          4.8    21625      9  2017      Fiction
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [150 rows x 7 columns]

# %%
genero=libros["Genre"]=="Fiction"
genero
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 545     True
# 546    False
# 547    False
# 548    False
# 549    False
# Name: Genre, Length: 550, dtype: bool

# %% [markdown]
# Podemos filtrar utilizando varias condiciones.

# %%
libros[mayor & genero]
# Out:
#                                                   Name             Author  \
# 3                               1984 (Signet Classics)      George Orwell
# 7                       A Gentleman in Moscow: A Novel        Amor Towles
# 10                           A Man Called Ove: A Novel    Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?    Bill Martin Jr.
# ..                                                 ...                ...
# 509                              To Kill a Mockingbird         Harper Lee
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 534                            Where the Crawdads Sing        Delia Owens
# 544                                             Wonder      R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)        Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# 3            4.7    21424      6  2017  Fiction
# 7            4.7    19699     15  2017  Fiction
# 10           4.6    23848      8  2017  Fiction
# 13           4.5     5153      5  2018  Fiction
# 40           4.9    14344      5  2017  Fiction
# ..           ...      ...    ...   ...      ...
# 509          4.8    26234      7  2019  Fiction
# 529          4.8     8170     13  2019  Fiction
# 534          4.8    87841     15  2019  Fiction
# 544          4.8    21625      9  2017  Fiction
# 545          4.9     9413      8  2019  Fiction
#
# [65 rows x 7 columns]

# %% [markdown]
# Y utilizar negación en las condiciones.

# %% [markdown]
# También es posible filtrar texto a través de *str.contains()*.

# %%
libros[libros["Author"].str.contains("Palacio")]
# Out:
#        Name         Author  User Rating  Reviews  Price  Year    Genre
# 540  Wonder  R. J. Palacio          4.8    21625      9  2013  Fiction
# 541  Wonder  R. J. Palacio          4.8    21625      9  2014  Fiction
# 542  Wonder  R. J. Palacio          4.8    21625      9  2015  Fiction
# 543  Wonder  R. J. Palacio          4.8    21625      9  2016  Fiction
# 544  Wonder  R. J. Palacio          4.8    21625      9  2017  Fiction

# %% [markdown]
# ## Funciones principales de Pandas

# %% [markdown]
# Mostrar las primeras dos líneas del dataframe.

# %%
libros.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# Mostrar qué columnas hay en el df, sus índices, cuántos valores en cada columna son no nulos, los tipos de datos de cada columna, cuántos registros hay y cuántas columnas hay.

# %%
libros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# Obtener diferentes estadísticos de las columnas numéricas.

# %%
libros.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# Mostrar los últimos 5 registros del df.

# %%
libros.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %% [markdown]
# Obtener el uso de la memoria de cada columna.

# %%
libros.memory_usage(deep=True)
# Out:
# Index            132
# Name           55233
# Author         34622
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          32040
# dtype: int64

# %% [markdown]
# Contar los valores por cada categoría de una columna.

# %%
libros["Author"].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %% [markdown]
# Obtener la información de un registro específico.

# %%
libros.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %% [markdown]
# Eliminar registros duplicados.

# %%
libros.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Eliminar el primer registro duplicado y conservar el último.

# %%
libros.drop_duplicates(keep="last")
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Ordenar los registros según los valores de una columna, de forma ascendente.

# %%
libros.sort_values("year",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18952\3305439.py in ?()
# ----> 1 libros.sort_values("year",ascending=False)
#
# c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# c:\Users\SENA\.conda\envs\sebitas\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'year'

# %% [markdown]
# Ordenar los registros según los valores de una columna, de forma descendente.

# %%
libros.sort_values("Year",ascending=False)
# Out:
#                                                   Name                 Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...            Jen Sincero
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 130  Girl, Wash Your Face: Stop Believing the Lies ...          Rachel Hollis
# ..                                                 ...                    ...
# 418  The Last Olympian (Percy Jackson and the Olymp...           Rick Riordan
# 38           Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 92   Eat This, Not That! Thousands of Simple Food S...        David Zinczenko
# 139  Good to Great: Why Some Companies Make the Lea...            Jim Collins
# 299                                  Sookie Stackhouse       Charlaine Harris
#
#      User Rating  Reviews  Price  Year        Genre
# 549          4.7    14331      8  2019  Non Fiction
# 294          4.8    23047      6  2019  Non Fiction
# 489          4.9     8842     10  2019      Fiction
# 263          4.7    10820      5  2019  Non Fiction
# 130          4.6    22288     12  2019  Non Fiction
# ..           ...      ...    ...   ...          ...
# 418          4.8     4628      7  2009      Fiction
# 38           4.6     9769     13  2009      Fiction
# 92           4.3      956     14  2009  Non Fiction
# 139          4.5     3457     14  2009  Non Fiction
# 299          4.7      973     25  2009      Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Convertir el tipo de dato de una columna.

# %%
libros["Name"]=libros["Name"].astype("string")
libros.dtypes
# Out:
# Name           string[python]
# Author                 object
# User Rating           float64
# Reviews                 int64
# Price                   int64
# Year                    int64
# Genre                  object
# dtype: object

# %% [markdown]
# ## Group by

# %% [markdown]
# Permite agrupar datos en funcion de los demas . Es decir, hacer el analisis del dataframe en funcion de una de las columnas.

# %% [markdown]
# Agrupar por una columna y mostrar el conteo de los datos de las demás columnas.

# %%
libros
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Agrupar por una columna y mostrar la media de los datos de las demás columnas.

# %%
libros.groupby("Author")
libros.groupby("Author").count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %% [markdown]
# La columna Author, en los casos anteriores, pasa a ser el indice. Podemos usar loc y acceder a un dato especifico del dataFrame. Agrupar por autor y mostrar la suma de los valores de las demas columnas para William Davis.

# %%
libros.groupby("Author").mean(numeric_only=True)
# Out:
#                             User Rating       Reviews      Price         Year
# Author
# Abraham Verghese               4.600000   4866.000000  11.000000  2010.500000
# Adam Gasiewski                 4.400000   3113.000000   6.000000  2017.000000
# Adam Mansbach                  4.800000   9568.000000   9.000000  2011.000000
# Adir Levy                      4.800000   8170.000000  13.000000  2019.000000
# Admiral William H. McRaven     4.700000  10199.000000  11.000000  2017.000000
# ...                                 ...           ...        ...          ...
# Walter Isaacson                4.566667   6222.666667  20.333333  2013.333333
# William Davis                  4.400000   7497.000000   6.000000  2012.500000
# William P. Young               4.600000  19720.000000   8.000000  2013.000000
# Wizards RPG Team               4.800000  16990.000000  27.000000  2018.000000
# Zhi Gang Sha                   4.600000    128.500000  11.500000  2011.000000
#
# [248 rows x 4 columns]

# %% [markdown]
# Si no quiero que la columna que estoy usando sea el índice sino que use los que por defecto tiene el dataframe entonces utilizo *.reset_index()*

# %%
libros.groupby("Author").sum().reset_index()
# Out:
#                          Author  \
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  User Rating  Reviews  \
# 0                   Cutting for StoneCutting for Stone          9.2     9732
# 1    Milk and Vine: Inspirational Quotes From Class...          4.4     3113
# 2                                 Go the F**k to Sleep          4.8     9568
# 3    What Should Danny Do? (The Power to Choose Ser...          4.8     8170
# 4    Make Your Bed: Little Things That Can Change Y...          4.7    10199
# ..                                                 ...          ...      ...
# 243              Leonardo da VinciSteve JobsSteve Jobs         13.7    18668
# 244  Wheat Belly: Lose the Wheat, Lose the Weight, ...          8.8    14994
# 245  The Shack: Where Tragedy Confronts EternityThe...          9.2    39440
# 246  Player's Handbook (Dungeons & Dragons)Player's...         14.4    50970
# 247  Divine Soul Mind Body Healing and Transmission...          9.2      257
#
#      Price  Year                              Genre
# 0       22  4021                     FictionFiction
# 1        6  2017                        Non Fiction
# 2        9  2011                            Fiction
# 3       13  2019                            Fiction
# 4       11  2017                        Non Fiction
# ..     ...   ...                                ...
# 243     61  6040  Non FictionNon FictionNon Fiction
# 244     12  4025             Non FictionNon Fiction
# 245     16  4026                     FictionFiction
# 246     81  6054              FictionFictionFiction
# 247     23  4022             Non FictionNon Fiction
#
# [248 rows x 7 columns]

# %% [markdown]
# Podemos hacer que el agrupamiento sea por determinadas funciones de agregación. En este caso, obtener el minimo y maximo de cada columna.

# %%
libros.groupby("Author").agg(["min","max"])
# Out:
#                                                                          Name  \
#                                                                           min
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Divine Soul Mind Body Healing and Transmission...
#
#                                                                                \
#                                                                           max
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                                    Steve Jobs
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Soul Healing Miracles: Ancient and New Sacred ...
#
#                            User Rating      Reviews        Price      Year  \
#                                    min  max     min    max   min max   min
# Author
# Abraham Verghese                   4.6  4.6    4866   4866    11  11  2010
# Adam Gasiewski                     4.4  4.4    3113   3113     6   6  2017
# Adam Mansbach                      4.8  4.8    9568   9568     9   9  2011
# Adir Levy                          4.8  4.8    8170   8170    13  13  2019
# Admiral William H. McRaven         4.7  4.7   10199  10199    11  11  2017
# ...                                ...  ...     ...    ...   ...  ..   ...
# Walter Isaacson                    4.5  4.6    3014   7827    20  21  2011
# William Davis                      4.4  4.4    7497   7497     6   6  2012
# William P. Young                   4.6  4.6   19720  19720     8   8  2009
# Wizards RPG Team                   4.8  4.8   16990  16990    27  27  2017
# Zhi Gang Sha                       4.6  4.6      37    220     6  17  2009
#
#                                         Genre
#                              max          min          max
# Author
# Abraham Verghese            2011      Fiction      Fiction
# Adam Gasiewski              2017  Non Fiction  Non Fiction
# Adam Mansbach               2011      Fiction      Fiction
# Adir Levy                   2019      Fiction      Fiction
# Admiral William H. McRaven  2017  Non Fiction  Non Fiction
# ...                          ...          ...          ...
# Walter Isaacson             2017  Non Fiction  Non Fiction
# William Davis               2013  Non Fiction  Non Fiction
# William P. Young            2017      Fiction      Fiction
# Wizards RPG Team            2019      Fiction      Fiction
# Zhi Gang Sha                2013  Non Fiction  Non Fiction
#
# [248 rows x 12 columns]

# %% [markdown]
# Agrupar por Author, obtener el mínimo y máximo de la columna Reviews y la media de los valores de la columna User Rating.

# %%
libros.groupby("Author").agg({"Reviews":["min","max"],"User Rating":"mean"})
# Out:
#                            Reviews        User Rating
#                                min    max        mean
# Author
# Abraham Verghese              4866   4866    4.600000
# Adam Gasiewski                3113   3113    4.400000
# Adam Mansbach                 9568   9568    4.800000
# Adir Levy                     8170   8170    4.800000
# Admiral William H. McRaven   10199  10199    4.700000
# ...                            ...    ...         ...
# Walter Isaacson               3014   7827    4.566667
# William Davis                 7497   7497    4.400000
# William P. Young             19720  19720    4.600000
# Wizards RPG Team             16990  16990    4.800000
# Zhi Gang Sha                    37    220    4.600000
#
# [248 rows x 3 columns]

# %% [markdown]
# También es posible agrupar por varias columnas.

# %%
libros.groupby(["Author","Year"]).count()
# Out:
#                        Name  User Rating  Reviews  Price  Genre
# Author           Year
# Abraham Verghese 2010     1            1        1      1      1
#                  2011     1            1        1      1      1
# Adam Gasiewski   2017     1            1        1      1      1
# Adam Mansbach    2011     1            1        1      1      1
# Adir Levy        2019     1            1        1      1      1
# ...                     ...          ...      ...    ...    ...
# Wizards RPG Team 2017     1            1        1      1      1
#                  2018     1            1        1      1      1
#                  2019     1            1        1      1      1
# Zhi Gang Sha     2009     1            1        1      1      1
#                  2013     1            1        1      1      1
#
# [493 rows x 5 columns]

# %% [markdown]
# ## Combinando dataframes

# %% [markdown]
# Existen diferentes formas de fusionar dos DataFrames. Esto se hace a través de la lógica de combinación.
#
# ![merge join](merge-join.jpg)
#
# - Left join: Da prioridad al DataFrame de la izquierda. Trae siempre los datos de la izquierda y las filas en común con el DataFrame de la derecha.
# - Right join: Da prioridad al DataFrame de la derecha. Trae siempre los datos de la derecha y las filas en común con el DataFrame de la izquierda.
# - Inner join: Trae solamente aquellos datos que son común en ambos DataFrame
# - Outer join: Trae los datos tanto del DataFrame de la izquierda como el de la derecha, incluyendo los datos que comparten ambos.
#
# ![merge join2](merge-join2.jpg)
#
# Concat - Axis 0: permite combinar dos dataframes a nivel de filas. Crecimiento vertical
#
# ![concat](concat.jpg)
#
# Concat - Axis 1: permite combinar dos dataframes a nivel de columnas. La organizacion por columnas no va a ser la misma para ambos  dataFrames, por tanto, se crearan valores NaN para rellenar los espacios vacios. Crecimiento horizontal
#
# ![concat2](concat2.jpg)

# %% [markdown]
# ### Concat

# %%
df1=pd.DataFrame({
'Α':['Α0','Α1','A2','A3'], 
'B':['B0','B1','B2','B3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3'] 
})

df2=pd.DataFrame({ 
'A':['A4','A5','A6','A7'],
'B':['B4','B5','B6','B7'],
'C':['C4','C5','C6','C7'],
'D':['D4','D5','D6','D7'] 
})

# %% [markdown]
# Concatenar dos dataframes por filas o axis = 0

# %%
pd.concat([df1,df2])
# Out:
#      Α   B   C   D    A
# 0   Α0  B0  C0  D0  NaN
# 1   Α1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 0  NaN  B4  C4  D4   A4
# 1  NaN  B5  C5  D5   A5
# 2  NaN  B6  C6  D6   A6
# 3  NaN  B7  C7  D7   A7

# %% [markdown]
# Como vemos, hay un error con los índices; vamos a corregirlos.

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#      Α   B   C   D    A
# 0   Α0  B0  C0  D0  NaN
# 1   Α1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 4  NaN  B4  C4  D4   A4
# 5  NaN  B5  C5  D5   A5
# 6  NaN  B6  C6  D6   A6
# 7  NaN  B7  C7  D7   A7

# %% [markdown]
# Concatenar dos dataframes por columnas, axis = 1

# %%
pd.concat([df1,df2],ignore_index=True,axis=1)
# Out:
#     0   1   2   3   4   5   6   7
# 0  Α0  B0  C0  D0  A4  B4  C4  D4
# 1  Α1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ### Merge

# %%
izq=pd.DataFrame({
'key':['k0','k1','k2','k3'],
'Α':['Α0','Α1','A2','A3'], 
'B':['B0','B1','B2','B3'],
})

der=pd.DataFrame({ 
'key':['k0','k1','k2','k3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3'] 
})

# %% [markdown]
# Unir el dataframe **der** a **izq** sobre una columna en específico.

# %%
izq.merge(der,on="key")
# Out:
#   key   Α   B   C   D
# 0  k0  Α0  B0  C0  D0
# 1  k1  Α1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %% [markdown]
# Habrán ocasiones en que no se tenga una columna con el mismo nombreen ambos dataframes y necesitamos separarlos de otra manera.

# %%
izq=pd.DataFrame({
'key':['k0','k1','k2','k3'],
'Α':['Α0','Α1','A2','A3'], 
'B':['B0','B1','B2','B3'],
})

der=pd.DataFrame({ 
'key':['k0','k1','k2','k3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3'] 
})

# %% [markdown]
# En este caso especificamos que queremos hacer un merge cruzando el dataframe de la izquierda con su columna *key* con el dataframe de la derecha y su columna *key_2*.

# %%
izq.merge(der,left_on="key",right_on="key_2")
# Out:
#   key   Α   B key_2   C   D
# 0  k0  Α0  B0    k0  C0  D0
# 1  k1  Α1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2

# %% [markdown]
# Si tenemos un NaN en nuestro DataFrame, pandas no lo detectará como un mach.

# %%
izq=pd.DataFrame({
'key':['k0','k1','k2','k3'],
'Α':['Α0','Α1','A2','A3'], 
'B':['B0','B1','B2','B3'],
})

der=pd.DataFrame({ 
'key_2':['k0','k1','k2',np.nan],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3'] 
})

# %% [markdown]
# Para solucionar esto debemos utilizar *how* para asignar una preferencia.

# %%
izq.merge(der,left_on="key",right_on="key_2",how="left")
# Out:
#   key   Α   B key_2    C    D
# 0  k0  Α0  B0    k0   C0   D0
# 1  k1  Α1  B1    k1   C1   D1
# 2  k2  A2  B2    k2   C2   D2
# 3  k3  A3  B3   NaN  NaN  NaN

# %% [markdown]
# ### Join

# %% [markdown]
# Join es otra herramienta para hacer exactamente lo mismo, una combinación. La diferencia es que join va a ir a los índices y no a columnas específicas.

# %%
izq=pd.DataFrame({

'Α':['Α0','Α1','A2'], 
'B':['B0','B1','B2']},
index=['k0','k1','k2']
)

der=pd.DataFrame({ 
'C':['C0','C1','C2'],
'D':['D0','D1','D2'] },
index=['k0','k3','k2'],
)

# %% [markdown]
# Combinamos **izq** con **der**.

# %%
izq.join(der)
# Out:
#      Α   B    C    D
# k0  Α0  B0   C0   D0
# k1  Α1  B1  NaN  NaN
# k2  A2  B2   C2   D2

# %% [markdown]
# Traer todos los datos aunque no hagan match.

# %%
izq.join(der,how="outer")
# Out:
#       Α    B    C    D
# k0   Α0   B0   C0   D0
# k1   Α1   B1  NaN  NaN
# k2   A2   B2   C2   D2
# k3  NaN  NaN   C1   D1

# %% [markdown]
# ¿Cuál es la principal diferencia entre merge y join en pandas?
#
# - Merge puede unificar df en base a los índices o a los valores de las columnas.
# - Join solo lo puede hacer en base a los índices. Es una caso específico de merge

# %% [markdown]
# ## Apply

# %% [markdown]
# Apply es un comando muy poderoso que nos deja aplicar funciones a nuestro DataFrame.

# %%
def doble(valor):
    return valor*2

# %% [markdown]
# A la columna *User Rating* le vamos a aplicar una función.

# %%
libros["User Rating"].apply(doble)
# Out:
# 0      9.4
# 1      9.2
# 2      9.4
# 3      9.4
# 4      9.6
#       ...
# 545    9.8
# 546    9.4
# 547    9.4
# 548    9.4
# 549    9.4
# Name: User Rating, Length: 550, dtype: float64

# %% [markdown]
# Esto podemos guardarlo en una nueva columna.

# %%
libros["User Rating x 2"]=libros["User Rating"].apply(doble)
libros
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      User Rating x 2
# 0                9.4
# 1                9.2
# 2                9.4
# 3                9.4
# 4                9.6
# ..               ...
# 545              9.8
# 546              9.4
# 547              9.4
# 548              9.4
# 549              9.4
#
# [550 rows x 8 columns]

# %% [markdown]
# Cualquier tipo de función se puede utilizar, incluso lambdas.

# %%
libros["User Rating"].apply(lambda x: x*3)
# Out:
# 0      14.1
# 1      13.8
# 2      14.1
# 3      14.1
# 4      14.4
#        ...
# 545    14.7
# 546    14.1
# 547    14.1
# 548    14.1
# 549    14.1
# Name: User Rating, Length: 550, dtype: float64

# %% [markdown]
# Podemos hacer un apply al dataframe como tal a partir de varias condiciones; debemos especificar a qué lo vamos a aplicar, si filas o columnas.

# %%
libros.apply(lambda x: x["User Rating"]*2 if x["Genre"]=="Fictin" else x["User Rating"],axis=1)
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Length: 550, dtype: float64
